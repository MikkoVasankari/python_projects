# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Auto.csv')

# %%
print(df.columns)
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'num_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 26

# %%
print(len(df.iloc[0:]))
# Out:
# 205

# %%
print(df.loc[:])
# Out:
#      symboling  normalized_losses         make fuel_type aspiration num_doors  \
# 0            3                NaN  alfa-romero       gas        std       two
# 1            3                NaN  alfa-romero       gas        std       two
# 2            1                NaN  alfa-romero       gas        std       two
# 3            2              164.0         audi       gas        std      four
# 4            2              164.0         audi       gas        std      four
# ..         ...                ...          ...       ...        ...       ...
# 200         -1               95.0        volvo       gas        std      four
# 201         -1               95.0        volvo       gas      turbo      four
# 202         -1               95.0        volvo       gas        std      four
# 203         -1               95.0        volvo    diesel      turbo      four
# 204         -1               95.0        volvo       gas      turbo      four
#
# ...

# %%
print(df['price'].mean())
# Out:
# 13207.129353233831

# %%
print(df.loc[df['num_doors'] == "four"])
# Out:
#      symboling  normalized_losses   make fuel_type aspiration num_doors  \
# 3            2              164.0   audi       gas        std      four
# 4            2              164.0   audi       gas        std      four
# 6            1              158.0   audi       gas        std      four
# 7            1                NaN   audi       gas        std      four
# 8            1              158.0   audi       gas      turbo      four
# ..         ...                ...    ...       ...        ...       ...
# 200         -1               95.0  volvo       gas        std      four
# 201         -1               95.0  volvo       gas      turbo      four
# 202         -1               95.0  volvo       gas        std      four
# 203         -1               95.0  volvo    diesel      turbo      four
# 204         -1               95.0  volvo       gas      turbo      four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
df = df.drop(columns=['symboling'])

# %%
df['Size'] = df['wheel_base'] * df['length'] * df['height']
print(df.head(10))
# Out:
#    normalized_losses         make fuel_type aspiration num_doors   body_style  \
# 0                NaN  alfa-romero       gas        std       two  convertible
# 1                NaN  alfa-romero       gas        std       two  convertible
# 2                NaN  alfa-romero       gas        std       two    hatchback
# 3              164.0         audi       gas        std      four        sedan
# 4              164.0         audi       gas        std      four        sedan
# 5                NaN         audi       gas        std       two        sedan
# 6              158.0         audi       gas        std      four        sedan
# 7                NaN         audi       gas        std      four        wagon
# 8              158.0         audi       gas      turbo      four        sedan
# 9                NaN         audi       gas      turbo       two    hatchback
#
#   drive_wheels engine_location  wheel_base  length  ...  fuel_system  bore  \
# ...

# %%
M = print(df['price'].mean())
# Out:
# 13207.129353233831

# %%
M = df['price'].mean()

df['Business'] = df['price'] > M

df['Economy'] = df['price'] <= M

df.sort_values('price',ascending=True)
# Out:
#      normalized_losses           make fuel_type aspiration num_doors  \
# 138               83.0         subaru       gas        std       two
# 18               121.0      chevrolet       gas        std       two
# 50               104.0          mazda       gas        std       two
# 150               87.0         toyota       gas        std       two
# 76               161.0     mitsubishi       gas        std       two
# ..                 ...            ...       ...        ...       ...
# 74                 NaN  mercedes-benz       gas        std       two
# 9                  NaN           audi       gas      turbo       two
# 44                 NaN          isuzu       gas        std       two
# 45                 NaN          isuzu       gas        std      four
# 129                NaN        porsche       gas        std       two
#
#     body_style drive_wheels engine_location  wheel_base  length  ...  stroke  \
# ...

# %%
M = df['price'].mean()

business_df = df['Business'] = df['price'] > M

economy_df = df['Economy'] = df['price'] <= M

df.sort_values('price',ascending=True)

business_df.to_csv('business.csv')

economy_df.to_csv('economy.csv')
